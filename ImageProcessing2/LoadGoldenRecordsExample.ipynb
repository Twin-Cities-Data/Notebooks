# %%
from GoldenRecords import golden

# %%
import pandas as pd

# %%
golden[0]
# Out:
# {'filename': 'throw1.mp4',
#  'score': 6,
#  'one_thing_to_improve': 'Athlete should set left heel down when left toe is facing 12:00 and twist in the middle during the wind-up to set weight properly.'}

# %%
pd.DataFrame(golden)
# Out:
#                filename  score  \
# 0            throw1.mp4      6
# 1            throw2.mp4      8
# 2            throw3.mp4      5
# 3            throw4.mp4      9
# 4            throw5.mp4      7
# 5            throw6.mp4      5
# 6            throw7.mp4      5
# 7            throw8.mp4      5
# 8            throw9.mp4      5
# 9           throw10.mp4      5
# 10          throw11.mp4      7
# 11          throw12.mp4      6
# 12    videoplayback.mp4      9
# 13  videoplayback-2.mp4      9
# 14  videoplayback-3.mp4      7
# 15  videoplayback-4.mp4      5
# 16  videoplayback-5.mp4      9
# 17  videoplayback-6.mp4      5
# 18  videoplayback-7.mp4      8
#
#                                  one_thing_to_improve
# 0   Athlete should set left heel down when left to...
# 1   Left arm and shoulder block appears to be late...
# 2   Athlete looks over the left shoulder for the e...
# 3   Athlete appears to land early in the sprint; t...
# ...
